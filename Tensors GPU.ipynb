# %%
import torch

# %%
device=torch.device("cuda")

# %%
#creating a new tensor on GPU
torch.rand(3,4,device=device)
# Out:
# tensor([[0.0188, 0.4765, 0.9656, 0.6938],
#         [0.9268, 0.3957, 0.2028, 0.8745],
#         [0.5151, 0.9399, 0.5559, 0.5987]], device='cuda:0')

# %%
#moving tensor to GPU
a=torch.rand(3,4)
a.to(device)
# Out:
# tensor([[0.7171, 0.3318, 0.5199, 0.5253],
#         [0.5938, 0.1648, 0.5914, 0.2874],
#         [0.0387, 0.2513, 0.5154, 0.2414]], device='cuda:0')
